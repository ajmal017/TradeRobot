# %%
import pandas as pd
import pandas_datareader.data as web
import datetime

# %%
df = pd.DataFrame(columns=['Ticker'])
# df.index.name = 'N'

# %%
tickers = ['AAPL', 'MCD', 'SPY', 'VNQ']
for ticker in tickers:
    df.loc[len(df.index)] = ticker

# %%
df = df.sort_values(by='Ticker')

# %%
df.head()
# Out:
#   Ticker
# N
# 0   AAPL
# 1    MCD
# 2    SPY
# 3    VNQ

# %%
df.to_csv('Data\TickersList.csv')

# %%
df = pd.read_csv('Data\TickersList.csv', index_col=0)

# %%
df = pd.read_csv('Data\TickersList.csv', index_col=0)
df = df.sort_values(by='Ticker')
df.reset_index(drop=True, inplace=True)
df.to_csv('Data\TickersList.csv')

# %%
df.head()
# Out:
#   Ticker
# 0   AAPL
# 1      C
# 2   CSCO
# 3    MCD
# 4    SPY

# %%
for ticker in df['Ticker']:
    ticker_df = pd.read_csv(f'Data\\{ticker}.csv')

# %%
ticker_df['Date'] = ticker_df['Date'].astype('datetime64[ns]')

# %%
ticker_df.head()
# Out:
#          Date        High         Low        Open       Close   Volume  \
# 0  2010-09-09  102.500000  101.139999  102.500000  101.320000  26500.0
# 1  2010-09-10  101.860001  101.300003  101.680000  101.779999   8600.0
# 2  2010-09-13  103.139999  102.500000  102.959999  103.059998  33700.0
# 3  2010-09-14  103.480003  102.379997  102.839996  103.040001  59400.0
# 4  2010-09-15  103.379997  102.400002  102.620003  103.300003   9200.0
#
#    Adj Close
# 0  83.534241
# 1  83.913506
# 2  84.968819
# 3  84.952339
# 4  85.166672

# %%
ticker_df['Close'].iloc[-1]
# Out:
# 283.8699951171875

# %%
ticker_df.dtypes
# Out:
# Date         datetime64[ns]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume              float64
# Adj Close           float64
# dtype: object

# %%
start = ticker_df['Date'].max().date()+ datetime.timedelta(days=2)
end = datetime.datetime.today().date()

# %%
start
# Out:
# datetime.date(2020, 2, 2)

# %%
end
# Out:
# datetime.date(2020, 3, 3)

# %%
new_ticker_df = web.DataReader(ticker, "yahoo", start=start, end=end).reset_index()

# %%
new_ticker_df.head()
# Out:
#         Date       High        Low       Open      Close   Volume  Adj Close
# 0 2020-02-03  94.949997  93.849998  93.879997  94.239998  7510000  94.239998
# 1 2020-02-04  95.599998  94.320000  94.580002  95.209999  4422900  95.209999
# 2 2020-02-05  95.629997  95.050003  95.389999  95.269997  4413700  95.269997
# 3 2020-02-06  95.870003  95.410004  95.550003  95.589996  3327500  95.589996
# 4 2020-02-07  95.830002  95.320000  95.720001  95.570000  3176200  95.570000

# %%
new_ticker_df.dtypes
# Out:
# Date         datetime64[ns]
# High                float64
# Low                 float64
# Open                float64
# Close               float64
# Volume                int64
# Adj Close           float64
# dtype: object

# %%
ticker_df = ticker_df.append(new_ticker_df, ignore_index=True)

# %%
ticker_df.set_index(['Date'], inplace=True)

# %%
ticker_df.tail(30)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2020-01-17  95.029999  94.519997  94.580002  94.720001   3581300.0  94.720001
# 2020-01-21  95.690002  94.589996  94.839996  95.620003   4217400.0  95.620003
# 2020-01-22  96.150002  94.820000  95.849998  94.980003   5024300.0  94.980003
# 2020-01-23  95.820000  94.690002  95.089996  95.779999   4825000.0  95.779999
# 2020-01-24  96.040001  95.160004  95.900002  95.449997   3518100.0  95.449997
# 2020-01-27  95.309998  94.730003  94.959999  94.989998   3047000.0  94.989998
# 2020-01-28  95.669998  94.970001  95.150002  95.370003   3006100.0  95.370003
# 2020-01-29  95.779999  94.930000  95.660004  95.019997   3785500.0  95.019997
# 2020-01-30  95.290001  94.599998  94.769997  95.089996   4142400.0  95.089996
# 2020-01-31  95.099998  93.669998  95.000000  93.930000   6370900.0  93.930000
# 2020-02-03  94.949997  93.849998  93.879997  94.239998   7510000.0  94.239998
# 2020-02-04  95.599998  94.320000  94.580002  95.209999   4422900.0  95.209999
# 2020-02-05  95.629997  95.050003  95.389999  95.269997   4413700.0  95.269997
# 2020-02-06  95.870003  95.410004  95.550003  95.589996   3327500.0  95.589996
# 2020-02-07  95.830002  95.320000  95.720001  95.570000   3176200.0  95.570000
# 2020-02-10  96.660004  95.839996  95.949997  96.639999   4457000.0  96.639999
# 2020-02-11  97.959999  96.970001  96.970001  97.370003   5362200.0  97.370003
# 2020-02-12  98.250000  97.129997  97.529999  97.949997   6298700.0  97.949997
# 2020-02-13  98.730003  97.750000  97.930000  98.540001   3683500.0  98.540001
# 2020-02-14  99.580002  98.639999  98.769997  99.559998   3004800.0  99.559998
# 2020-02-18  99.690002  98.879997  99.620003  99.449997   4186800.0  99.449997
# 2020-02-19  99.500000  98.099998  99.500000  98.110001   4415200.0  98.110001
# 2020-02-20  99.330002  97.870003  98.160004  99.279999   5556500.0  99.279999
# 2020-02-21  99.720001  99.029999  99.269997  99.570000   3670800.0  99.570000
# 2020-02-24  99.129997  97.750000  98.389999  98.209999   5214600.0  98.209999
# 2020-02-25  98.620003  95.290001  98.440002  95.550003   7378900.0  95.550003
# 2020-02-26  96.459999  94.470001  95.739998  94.519997   9407200.0  94.519997
# 2020-02-27  93.300003  89.489998  93.099998  89.489998  11869100.0  89.489998
# 2020-02-28  88.199997  84.660004  87.500000  87.330002  22471800.0  87.330002
# 2020-03-02  91.070000  87.160004  87.650002  91.059998  14249900.0  91.059998

# %%
ticker_df.to_csv(f'Data\\{ticker}_new.csv')

# %%
# datetime.datetime.strptime(ticker_df['Date'].iloc[-1], '%Y-%m-%d').date()
# ticker_df['Date'].iloc[-1]
# ticker_df.index.max()
# Out:
# '2020-01-31'

# %%
# start = ticker_df['Date'].iloc[-1]
# start = ticker_df.index.max()
# end = datetime.datetime.today().date()

# %%
def check_balance(ticker, count):
    """
    Check the available sum for buy specified ticker.
    :param ticker:
    :param count:
    :return:
    """
    df = self.read_data(ticker)
    price = df.loc[:, 'Close'][-1]
    amount = price * count

    if self.balance() > amount:
        return True
    else:
        return False

def read_data(ticker, path='Data\\'):
    """
    Read the stock data of ticker from file '{path}{ticker}.csv'
    :param path:
    :param ticker:
    :return: Pandas DataFrame with stock data of ticker
    """
    df = pd.read_csv(f'{path}{ticker}.csv')
    return df

# %%
df = read_data('AAPL')
df
# Out:
#             Date        High         Low        Open       Close       Volume  \
# 0     2009-12-31   30.478571   30.080000   30.447144   30.104286   88102700.0
# 1     2010-01-04   30.642857   30.340000   30.490000   30.572857  123432400.0
# 2     2010-01-05   30.798571   30.464285   30.657143   30.625713  150476200.0
# 3     2010-01-06   30.747143   30.107143   30.625713   30.138571  138040000.0
# 4     2010-01-07   30.285715   29.864286   30.250000   30.082857  119282800.0
# ...          ...         ...         ...         ...         ...          ...
# 2553  2020-02-25  302.529999  286.130005  300.950012  288.079987   57668400.0
# 2554  2020-02-26  297.880005  286.500000  286.529999  292.649994   49513700.0
# 2555  2020-02-27  286.000000  272.959991  281.100006  273.519989   80151400.0
# 2556  2020-02-28  278.410004  256.369995  257.260010  273.359985  106721200.0
# 2557  2020-03-02  301.440002  277.720001  282.279999  298.809998   85160300.0
#
#        Adj Close
# 0      26.131752
# 1      26.538483
# 2      26.584366
# 3      26.161509
# 4      26.113146
# ...          ...
# 2553  288.079987
# 2554  292.649994
# 2555  273.519989
# 2556  273.359985
# 2557  298.809998
#
# [2558 rows x 7 columns]

# %%
df['Close'].iloc[-1]
# Out:
# 298.80999755859375
